# %% [markdown]
# 𝙆𝙡𝙞𝙗 0.1.5

# %% [markdown]
# pip install klib

# %% [markdown]
# Customized data preprocessing functions for frequent tasks.

# %%
! pip install klib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ✅ When Should You Use klib (Not Other Libraries)?
#
# Use klib when you want FAST and AUTOMATIC data understanding and cleaning with very little coding.

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import klib

# %% [markdown]
# # Klib.describe functions for visualizing datasets

# %%
# klib.describe functions for visualizing datasets
#  klib.cat_plot(df) #returns a visualization of the number and frequency of categorical features
#  klib.corr_mat(df) # return a color-encoded Correlation matrix
#  klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correletions
#  klib.dist_plot(df) # returns a dristribution plot for every numeric feature 
#  klib.missingval_plot(df) # returns a figure containing information about missing values

# %%
klib.cat_plot(df)
# Out:
# C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\klib\describe.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   data.loc[data[col].isin(value_counts_idx_top), col] = 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9124\2222831409.py in <cell line: 0>()
# ----> 1 klib.cat_plot(df)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\klib\describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     125         data[col] = data[col].rolling(2, min_periods=1).mean()
#     126
# ...

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_ddc2f_row0_col0, #T_ddc2f_row0_col4, #T_ddc2f_row0_col5, #T_ddc2f_row1_col1, #T_ddc2f_row1_col3, #T_ddc2f_row1_col4, #T_ddc2f_row1_col6, #T_ddc2f_row1_col7, #T_ddc2f_row2_col2, #T_ddc2f_row2_col5, #T_ddc2f_row2_col6, #T_ddc2f_row2_col7, #T_ddc2f_row3_col1, #T_ddc2f_row3_col3, #T_ddc2f_row3_col4, #T_ddc2f_row3_col5, #T_ddc2f_row4_col0, #T_ddc2f_row4_col1, #T_ddc2f_row4_col3, #T_ddc2f_row4_col4, #T_ddc2f_row4_col5, #T_ddc2f_row5_col0, #T_ddc2f_row5_col2, #T_ddc2f_row5_col3, #T_ddc2f_row5_col4, #T_ddc2f_row5_col5, #T_ddc2f_row6_col1, #T_ddc2f_row6_col2, #T_ddc2f_row6_col6, #T_ddc2f_row6_col7, #T_ddc2f_row7_col1, #T_ddc2f_row7_col2, #T_ddc2f_row7_col6, #T_ddc2f_row7_col7 {
#   color: None;
# }
# ...

# %%
klib.corr_plot(df)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %% [markdown]
# # klib.clean functions for cleaning datasets

# %%
#  klib.data_cleaning(df)  # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
#  klib.clean_column_names(df)  # cleans and standardizes column names also called inside data_cleaning()
#  klib.convert_datatypes(df)  # converts existing to more efficient dtypes also called inside data_cleaning()
#  klib.drop_missing(df)  # drops missing values, also called in data_cleaning()
#  klib.mv_col_handling(df)  # drops features with high missing values based on informational content
#  klib.pool_duplicate_subsets(df)  # pools subset cols based on duplicates with min. loss of information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_clean=klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15) - Remaining NAs: 692
#
#
# Dropped rows: 107
#      of which 107 duplicates. (Rows (first 150 shown): [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int8
#  1   pclass       784 non-null    int8
#  2   sex          784 non-null    category
#  3   age          678 non-null    float32
#  4   sibsp        784 non-null    int8
#  5   parch        784 non-null    int8
#  6   fare         784 non-null    float32
#  7   embarked     782 non-null    category
#  8   class        784 non-null    category
#  9   who          784 non-null    category
#  10  adult_male   784 non-null    boolean
#  11  deck         202 non-null    category
#  12  embark_town  782 non-null    category
#  13  alive        784 non-null    category
#  14  alone        784 non-null    boolean
# dtypes: boolean(2), category(7), float32(2), int8(4)
# memory usage: 18.8 KB
